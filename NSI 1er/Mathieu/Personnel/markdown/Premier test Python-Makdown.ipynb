# %%
print("test")
# Out:
# test

# %% [markdown]
# # Test

# %% [markdown]
# print("Test python")
# # Test Markdown

# %%
print("Test python")
# Out:
# Test python

# %% [markdown]
# Test Markdown

# %% [raw]
# Test Markdown

# %% [markdown]
# # Test Markdown
